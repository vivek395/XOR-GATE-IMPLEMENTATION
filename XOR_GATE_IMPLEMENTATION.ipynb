# %% [markdown]
# <a href="https://colab.research.google.com/github/vivek395/XOR-GATE-IMPLEMENTATION-1/blob/main/XOR_GATE_IMPLEMENTATION.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from keras.models import Sequential
from keras.layers.core import Dense

training_data=np.array([[0,0],[0,1],[1,0],[1,1]],"float32")
target_data=np.array([[0],[1],[1],[0]],"float32")

model=Sequential()
model.add(Dense(16,input_dim=2,activation='relu'))
model.add(Dense(1,activation='sigmoid'))
model.compile(loss='mean_squared_error',
                    optimizer='adam',
                    metrics=['binary_accuracy'])
model.fit(training_data,target_data,epochs=1000)
scores=model.evaluate(training_data,target_data)

print("\n%s: %.2f%%" % (model.metrics_names[1],scores[1]*100))
print(model.predict(training_data).round())
# Out:
# Epoch 1/1000
# 1/1 [==============================] - 1s 689ms/step - loss: 0.2698 - binary_accuracy: 0.5000
# Epoch 2/1000
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2694 - binary_accuracy: 0.2500
# Epoch 3/1000
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2690 - binary_accuracy: 0.2500
# Epoch 4/1000
# 1/1 [==============================] - 0s 18ms/step - loss: 0.2686 - binary_accuracy: 0.2500
# Epoch 5/1000
# 1/1 [==============================] - 0s 12ms/step - loss: 0.2683 - binary_accuracy: 0.2500
# Epoch 6/1000
# 1/1 [==============================] - 0s 12ms/step - loss: 0.2679 - binary_accuracy: 0.0000e+00
# Epoch 7/1000
# 1/1 [==============================] - 0s 11ms/step - loss: 0.2675 - binary_accuracy: 0.0000e+00
# Epoch 8/1000
# 1/1 [==============================] - 0s 14ms/step - loss: 0.2672 - binary_accuracy: 0.0000e+00
# Epoch 9/1000
# ...
